# %%
# imports
import requests
import json
import pandas as pd
import os

# %%
bike_stations_df = pd.read_csv('bike_stations.csv', index_col = 0)

# %%
bike_stations_df
# Out:
#                             Station Name  Available Bikes  Empty Slots  \
# 0               W 100 St & Manhattan Ave                5           29
# 1             7 Ave & Central Park South                2           76
# 2                Bedford Ave & Bergen St                2           15
# 3                         28 St & 41 Ave               12           12
# 4     Frederick Douglass Blvd & W 112 St               14           14
# ...                                  ...              ...          ...
# 1974                99 St & Astoria Blvd                0           22
# 1975                E 34 St & Church Ave                6           19
# 1976        Snyder Ave & Schenectady Ave                3           16
# 1977                      99 St & 32 Ave                5           14
# 1978                      32 Ave & 77 St               17            5
#
#        Latitude  Longitude
# 0     40.795000 -73.964500
# 1     40.766741 -73.979069
# 2     40.676368 -73.952918
# 3     40.751047 -73.937970
# 4     40.801694 -73.957145
# ...         ...        ...
# 1974  40.761960 -73.870420
# 1975  40.651160 -73.945770
# 1976  40.650000 -73.932960
# 1977  40.758960 -73.869760
# 1978  40.757270 -73.890240
#
# [1979 rows x 5 columns]

# %%
bike_stations1_df = bike_stations_df.iloc[:500]
bike_stations2_df = bike_stations_df.iloc[500:1000]
bike_stations3_df = bike_stations_df.iloc[1000:1500]
bike_stations4_df = bike_stations_df.iloc[1500:]

# %% [markdown]
# # Foursquare

# %% [markdown]
# Send a request to Foursquare with a small radius (1000m) for all the bike stations in your city of choice.

# %%
def query_foursquare_for_places(lat, lng, radius=1000, limit = 50):
    url = f"https://api.foursquare.com/v3/places/search"
    FOURSQUARE_API_VERSION = '20230820'
    params = {
        'v': FOURSQUARE_API_VERSION,
        'll': f"{lat},{lng}",
        'radius': radius
    }
    
    api_key = os.getenv('foursquare_API')
    
    # Create dictionary for headers
    headers = {"Accept": "application/json"}
    # Add key with our API KEY
    headers['Authorization'] = api_key

    try:
        response = requests.get(url, headers=headers, params=params)
        #print(response)
        #print("Response content:", response.content)  # Print the raw response content
        response_data = response.json()
        print(response.json())
        
        if 'results' in response_data:
            places = response_data['results']
            return places
        else:
            print("No Place of Interest found")
            return []         

    except requests.exceptions.RequestException as e:
        print("Error making API request:", e)
        return []

# %%
if bike_stations_df is not None:
    for index, row in bike_stations_df.iterrows():
        print(f"Station Name: {row['Station Name']}")
        print(f"Available Bikes: {row['Available Bikes']}")
        print(f"Empty Slots: {row['Empty Slots']}")
        print(f"Latitude: {row['Latitude']}")
        print(f"Longitude: {row['Longitude']}")
        
        query_foursquare_for_places(row['Latitude'], row['Longitude'])
# Out:
# Station Name: W 100 St & Manhattan Ave
# Available Bikes: 5
# Empty Slots: 29
# Latitude: 40.795
# Longitude: -73.9645
# {'results': [{'fsq_id': '4fdc9a79e4b0735a6deafc25', 'categories': [{'id': 13035, 'name': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}}], 'chains': [{'id': 'ab4c54c0-d68a-012e-5619-003048cad9da', 'name': 'Starbucks'}], 'distance': 100, 'geocodes': {'main': {'latitude': 40.794937, 'longitude': -73.965633}, 'roof': {'latitude': 40.794937, 'longitude': -73.965633}}, 'link': '/v3/places/4fdc9a79e4b0735a6deafc25', 'location': {'address': '805 Columbus Ave', 'address_extended': 'Frnt 2', 'census_block': '360610185001000', 'country': 'US', 'cross_street': 'at W 100th St', 'dma': 'New York', 'formatted_address': '805 Columbus Ave (at W 100th St), New York, NY 10025', 'locality': 'New York', 'postcode': '10025', 'region': 'NY'}, 'name': 'Starbucks', 'related_places': {}, 'timezone': 'America/New_York'}, {'fsq_id': '4a95cf86f964a520c92420e3', 'categories': [{'id': 17069, 'name': 'Grocery Store', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_', 'suffix': '.png'}}], 'chains': [{'id': 'c356152c-f98c-4c43-8a1e-1d16cc9ea1c8', 'name': 'Whole Foods'}], 'distance': 204, 'geocodes': {'main': {'latitude': 40.794254, 'longitude': -73.966918}, 'roof': {'latitude': 40.794254, 'longitude': -73.966918}}, 'link': '/v3/places/4a95cf86f964a520c92420e3', 'location': {'address': '808 Columbus Ave', 'census_block': '360610185002000', 'country': 'US', 'cross_street': 'at W 97th St', 'dma': 'New York', 'formatted_address': '808 Columbus Ave (at W 97th St), New York, NY 10025', 'locality': 'New York', 'postcode': '10025', 'region': 'NY'}, 'name': 'Whole Foods', 'related_places': {'children': [{'fsq_id': '5d01891b0e32390038ed9ad6', 'name': 'Dish & Saucery'}]}, 'timezone': 'America/New_York'}, {'fsq_id': '5037e21fe4b0b68ee3d6546f', 'categories': [{'id': 13035, 'name': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}}, {'id': 13065, 'name': 'Restaurant', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_', 'suffix': '.png'}}], 'chains': [], 'distance': 310, 'geocodes': {'main': {'latitude': 40.793322, 'longitude': -73.967451}, 'roof': {'latitude': 40.793322, 'longitude': -73.967451}}, 'link': '/v3/places/5037e21fe4b0b68ee3d6546f', 'location': {'address': '750 Columbus Ave', 'census_block': '360610181003000', 'country': 'US', 'cross_street': 'btwn W 96th & W 97th St', 'dma': 'New York', 'formatted_address': '750 Columbus Ave (btwn W 96th & W 97th St), New York, NY 10025', 'locality': 'New York', 'postcode': '10025', 'region': 'NY'}, 'name': 'Birch Coffee', 'related_places': {}, 'timezone': 'America/New_York'}, {'fsq_id': '4b67aad0f964a520265a2be3', 'categories': [{'id': 16026, 'name': 'Monument', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_monument_', 'suffix': '.png'}}, {'id': 16028, 'name': 'Nature Preserve', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/naturepreserve_', 'suffix': '.png'}}, {'id': 16041, 'name': 'Plaza', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_', 'suffix': '.png'}}, {'id': 17117, 'name': 'Sporting Goods Retail', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_', 'suffix': '.png'}}], 'chains': [], 'distance': 391, 'geocodes': {'main': {'latitude': 40.791511, 'longitude': -73.964539}}, 'link': '/v3/places/4b67aad0f964a520265a2be3', 'location': {'address': 'Central Park W , New York, NY, United States', 'census_block': '360610143001013', 'country': 'US', 'cross_street': 'at W 96th St', 'dma': 'New York', 'formatted_address': 'Central Park W , New York, NY, United States (at W 96th St), New York, NY 10025', 'locality': 'New York', 'postcode': '10025', 'region': 'NY'}, 'name': 'Central Park - Gate Of All Saints', 'related_places': {'parent': {'fsq_id': '412d2800f964a520df0c1fe3', 'name': 'Central Park'}}, 'timezone': 'America/New_York'},  ...
# Station Name: 7 Ave & Central Park South
# Available Bikes: 2
# Empty Slots: 76
# Latitude: 40.7667405590595
# Longitude: -73.9790689945221
# {'results': [{'fsq_id': '4e1e32498877933f6973c411', 'categories': [{'id': 13079, 'name': 'Brazilian Restaurant', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/argentinian_', 'suffix': '.png'}}], 'chains': [], 'distance': 16, 'geocodes': {'main': {'latitude': 40.766621, 'longitude': -73.978867}, 'roof': {'latitude': 40.766621, 'longitude': -73.978867}}, 'link': '/v3/places/4e1e32498877933f6973c411', 'location': {'census_block': '360610137001000', 'country': 'US', 'cross_street': '', 'dma': 'New York', 'formatted_address': 'New York, NY 10019', 'locality': 'New York', 'postcode': '10019', 'region': 'NY'}, 'name': 'NYAC Tap Room', 'related_places': {'parent': {'fsq_id': '4b69aef2f964a52058ad2be3', 'name': 'New York Athletic Club'}}, 'timezone': 'America/New_York'}, {'fsq_id': '4a0babaaf964a52007751fe3', 'categories': [{'id': 13236, 'name': 'Italian Restaurant', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}}, {'id': 13314, 'name': 'New American Restaurant', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_', 'suffix': '.png'}}, {'id': 13338, 'name': 'Seafood Restaurant', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_', 'suffix': '.png'}}], 'chains': [], 'distance': 189, 'geocodes': {'drop_off': {'latitude': 40.767391, 'longitude': -73.981126}, 'main': {'latitude': 40.76737, 'longitude': -73.981125}, 'roof': {'latitude': 40.76737, 'longitude': -73.981125}}, 'link': '/v3/places/4a0babaaf964a52007751fe3', 'location': {'address': '240 Central Park S', 'census_block': '360610137004000', 'country': 'US', 'cross_street': 'at 59th St & Broadway', 'dma': 'New York', 'formatted_address': '240 Central Park S (at 59th St & Broadway), New York, NY 10019', 'locality': 'New York', 'postcode': '10019', 'region': 'NY'}, 'name': 'Marea', 'related_places': {}, 'timezone': 'America/New_York'}, {'fsq_id': '3fd66200f964a520b6e71ee3', 'categories': [{'id': 10037, 'name': 'Concert Hall', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_', 'suffix': '.png'}}, {'id': 10039, 'name': 'Music Venue', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_', 'suffix': '.png'}}, {'id': 10043, 'name': 'Theater', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_', 'suffix': '.png'}}], 'chains': [], 'distance': 193, 'geocodes': {'main': {'latitude': 40.76497, 'longitude': -73.97972}, 'roof': {'latitude': 40.765084, 'longitude': -73.979856}}, 'link': '/v3/places/3fd66200f964a520b6e71ee3', 'location': {'address': '57th Street and Seventh', 'address_extended': 'Ste 862', 'census_block': '360610137002001', 'country': 'US', 'cross_street': 'at W 57th St', 'dma': 'New York', 'formatted_address': '57th Street and Seventh (at W 57th St), New York, NY 10019', 'locality': 'New York', 'postcode': '10019', 'region': 'NY'}, 'name': 'Carnegie Hall', 'related_places': {'children': [{'fsq_id': '56f247a7498e93a37ea880db', 'name': 'Stern Auditorium / Perelman Stage'}, {'fsq_id': '4ae39d67f964a520489721e3', 'name': 'Weill Recital Hall'}, {'fsq_id': '4ace86aff964a5200bd120e3', 'name': 'Judy and Arthur Zankel Hall at Carnegie Hall'}]}, 'timezone': 'America/New_York'}, {'fsq_id': '4ba51a2bf964a52074dd38e3', 'categories': [{'id': 16030, 'name': 'Other Great Outdoors', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/outdoors_', 'suffix': '.png'}}], 'chains': [], 'distance': 231, 'geocodes': {'main': {'latitude': 40.768581, 'longitude': -73.978245}}, 'link': '/v3/places/4ba51a2bf964a52074dd38e3', 'location': {'address': 'Central Park Dr', 'census_block': '360610143001027', 'country': 'US', 'formatted_address': 'Central Park Dr, New York, NY 10065', 'locality': 'New York', 'postcode': '10065', 'region': 'NY'}, 'name': 'The Rocks', 'related_places': {'parent': {'fsq_id': '412d2800f964a520df0c1fe3', 'name': 'Central Park'}}, 't ...
# Station Name: Bedford Ave & Bergen St
# Available Bikes: 2
# Empty Slots: 15
# Latitude: 40.676368
# Longitude: -73.952918
# {'results': [{'fsq_id': '4bafd986f964a520d9253ce3', 'categories': [{'id': 16041, 'name': 'Plaza', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_', 'suffix': '.png'}}], 'chains': [], 'distance': 15, 'geocodes': {'main': {'latitude': 40.676395, 'longitude': -73.952497}, 'roof': {'latitude': 40.676395, 'longitude': -73.952497}}, 'link': '/v3/places/4bafd986f964a520d9253ce3', 'location': {'address': 'Bedford Avenue', 'census_block': '360470315003000', 'country': 'US', 'cross_street': 'at Bergen St', 'dma': 'New York', 'formatted_address': 'Bedford Avenue (at Bergen St), Brooklyn, NY 11216', 'locality': 'Brooklyn', 'postcode': '11216', 'region': 'NY'}, 'name': 'Grant Square', 'related_places': {}, 'timezone': 'America/New_York'}, {'fsq_id': '5a63c8bb64c8e1020c269ba0', 'categories': [{'id': 13035, 'name': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}}, {'id': 13065, 'name': 'Restaurant', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_', 'suffix': '.png'}}], 'chains': [], 'distance': 217, 'geocodes': {'main': {'latitude': 40.674234, 'longitude': -73.952676}, 'roof': {'latitude': 40.674234, 'longitude': -73.952676}}, 'link': '/v3/places/5a63c8bb64c8e1020c269ba0', 'location': {'address': '724 Prospect Pl', 'census_block': '360470317012001', 'country': 'US', 'cross_street': 'Rogers Ave', 'dma': 'New York', 'formatted_address': '724 Prospect Pl (Rogers Ave), Brooklyn, NY 11216', 'locality': 'Brooklyn', 'postcode': '11216', 'region': 'NY'}, 'name': 'Cafe Con Libros', 'related_places': {}, 'timezone': 'America/New_York'}, {'fsq_id': '583eed929526bc3d3e491401', 'categories': [{'id': 13034, 'name': 'Café', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_', 'suffix': '.png'}}, {'id': 13035, 'name': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}}, {'id': 13065, 'name': 'Restaurant', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_', 'suffix': '.png'}}], 'chains': [], 'distance': 219, 'geocodes': {'drop_off': {'latitude': 40.676125, 'longitude': -73.950453}, 'main': {'latitude': 40.676343, 'longitude': -73.950402}, 'roof': {'latitude': 40.676343, 'longitude': -73.950402}}, 'link': '/v3/places/583eed929526bc3d3e491401', 'location': {'address': '1077 Bergen St', 'census_block': '360470315003000', 'country': 'US', 'cross_street': 'at Nostrand Ave', 'dma': 'New York', 'formatted_address': '1077 Bergen St (at Nostrand Ave), Brooklyn, NY 11216', 'locality': 'Brooklyn', 'postcode': '11216', 'region': 'NY'}, 'name': 'Cafe Cotton Bean', 'related_places': {}, 'timezone': 'America/New_York'}, {'fsq_id': '5f88c1f9fcd49f1f07592a4b', 'categories': [{'id': 13003, 'name': 'Bar', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_', 'suffix': '.png'}}], 'chains': [], 'distance': 253, 'geocodes': {'drop_off': {'latitude': 40.67625, 'longitude': -73.955945}, 'main': {'latitude': 40.676349, 'longitude': -73.956202}, 'roof': {'latitude': 40.676349, 'longitude': -73.956202}}, 'link': '/v3/places/5f88c1f9fcd49f1f07592a4b', 'location': {'address': '644 Franklin Ave', 'census_block': '360470305002000', 'country': 'US', 'cross_street': '', 'dma': 'New York', 'formatted_address': '644 Franklin Ave, Brooklyn, NY 11238', 'locality': 'Brooklyn', 'postcode': '11238', 'region': 'NY'}, 'name': 'Rialto Grande', 'related_places': {}, 'timezone': 'America/New_York'}, {'fsq_id': '528e7b2411d2604c49c33eb6', 'categories': [{'id': 17069, 'name': 'Grocery Store', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_', 'suffix': '.png'}}], 'chains': [], 'distance': 228, 'geocodes': {'drop_off': {'latitude': 40.674328, 'longitude': -73.95375}, 'main': {'latitude': 40.674414, 'longitude': -73.953991}, 'roof': {'latitude': 40.674414, 'longitude': -73.953991}}, 'link': '/v3/places/528e7b2411d2604c49c33eb6', 'locati ...
# Station Name: 28 St & 41 Ave
# Available Bikes: 12
# Empty Slots: 12
# Latitude: 40.751047
# Longitude: -73.93797
# {'results': [{'fsq_id': '5f7f9a5d13aafe7a59e1054b', 'categories': [{'id': 13026, 'name': 'BBQ Joint', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_', 'suffix': '.png'}}], 'chains': [], 'distance': 206, 'geocodes': {'drop_off': {'latitude': 40.75281, 'longitude': -73.936662}, 'main': {'latitude': 40.752586, 'longitude': -73.93678}, 'roof': {'latitude': 40.752586, 'longitude': -73.93678}}, 'link': '/v3/places/5f7f9a5d13aafe7a59e1054b', 'location': {'address': '2720 40th Ave', 'census_block': '360810033011000', 'country': 'US', 'cross_street': '', 'dma': 'New York', 'formatted_address': '2720 40th Ave, Queens, NY 11101', 'locality': 'Queens', 'postcode': '11101', 'region': 'NY'}, 'name': 'John Brown Smokehouse', 'related_places': {}, 'timezone': 'America/New_York'}, {'fsq_id': '5c421048dbde11002535721b', 'categories': [{'id': 13035, 'name': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}}, {'id': 13040, 'name': 'Dessert Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_', 'suffix': '.png'}}, {'id': 13065, 'name': 'Restaurant', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_', 'suffix': '.png'}}], 'chains': [], 'distance': 264, 'geocodes': {'drop_off': {'latitude': 40.750267, 'longitude': -73.940894}, 'main': {'latitude': 40.750054, 'longitude': -73.940658}, 'roof': {'latitude': 40.750054, 'longitude': -73.940658}}, 'link': '/v3/places/5c421048dbde11002535721b', 'location': {'address': '4215 Crescent St', 'census_block': '360810019021003', 'country': 'US', 'cross_street': 'btwn Queens Plaza S & 42nd Rd', 'dma': 'New York', 'formatted_address': '4215 Crescent St (btwn Queens Plaza S & 42nd Rd), Queens, NY 11101', 'locality': 'Queens', 'postcode': '11101', 'region': 'NY'}, 'name': 'Chip City - LIC', 'related_places': {}, 'timezone': 'America/New_York'}, {'fsq_id': '598fc859112c6c66406c67fe', 'categories': [{'id': 13039, 'name': 'Deli', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_', 'suffix': '.png'}}], 'chains': [], 'distance': 279, 'geocodes': {'main': {'latitude': 40.749249, 'longitude': -73.940496}, 'roof': {'latitude': 40.749249, 'longitude': -73.940496}}, 'link': '/v3/places/598fc859112c6c66406c67fe', 'location': {'address': '4237 27th St', 'census_block': '360810019021008', 'country': 'US', 'cross_street': '', 'dma': 'New York', 'formatted_address': '4237 27th St, Long Island City, NY 11101', 'locality': 'Long Island City', 'postcode': '11101', 'region': 'NY'}, 'name': 'Olives Organic Market', 'related_places': {}, 'timezone': 'America/New_York'}, {'fsq_id': '5c269eb75bc27d002572ad19', 'categories': [{'id': 13003, 'name': 'Bar', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_', 'suffix': '.png'}}, {'id': 13000, 'name': 'Dining and Drinking', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_', 'suffix': '.png'}}, {'id': 13006, 'name': 'Beer Bar', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_', 'suffix': '.png'}}], 'chains': [], 'distance': 236, 'geocodes': {'main': {'latitude': 40.752672, 'longitude': -73.939623}, 'roof': {'latitude': 40.752672, 'longitude': -73.939623}}, 'link': '/v3/places/5c269eb75bc27d002572ad19', 'location': {'address': '2403 41st Ave', 'census_block': '360810033021006', 'country': 'US', 'cross_street': 'at 24th St', 'dma': 'New York', 'formatted_address': '2403 41st Ave (at 24th St), Long Island City, NY 11101', 'locality': 'Long Island City', 'postcode': '11101', 'region': 'NY'}, 'name': "THE HUNTRESS whiskey n' wings", 'related_places': {}, 'timezone': 'America/New_York'}, {'fsq_id': '636569d19cc7af2d1a96f1a2', 'categories': [{'id': 13035, 'name': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}}], 'chains': [], 'distance': 359, 'geocodes': {'drop_off': {'latitude': 40.749499, 'longitude': -73.941579}, ...
# Station Name: Frederick Douglass Blvd & W 112 St
# Available Bikes: 14
# Empty Slots: 14
# Latitude: 40.801694
# Longitude: -73.957145
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 9
#       6 print(f"Latitude: {row['Latitude']}")
#       7 print(f"Longitude: {row['Longitude']}")
# ----> 9 query_foursquare_for_places(row['Latitude'], row['Longitude'])
#
# Cell In[35], line 18, in query_foursquare_for_places(lat, lng, radius, limit)
#      15 headers['Authorization'] = api_key
#      17 try:
# ---> 18     response = requests.get(url, headers=headers, params=params)
#      19     #print(response)
#      20     #print("Response content:", response.content)  # Print the raw response content
#      21     response_data = response.json()
#
# File ~\anaconda3\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~\anaconda3\Lib\site-packages\requests\adapters.py:487, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     484     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     486 try:
# --> 487     resp = conn.urlopen(
#     488         method=request.method,
#     489         url=url,
#     490         body=request.body,
#     491         headers=request.headers,
#     492         redirect=False,
#     493         assert_same_host=False,
#     494         preload_content=False,
#     495         decode_content=False,
#     496         retries=self.max_retries,
#     497         timeout=timeout,
#     498         chunked=chunked,
#     499     )
#     501 except (ProtocolError, OSError) as err:
#     502     raise ConnectionError(err, request=request)
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461             httplib_response = conn.getresponse()
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     468     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     458 except TypeError:
#     459     # Python 3
#     460     try:
# --> 461         httplib_response = conn.getresponse()
#     462     except BaseException as e:
#     463         # Remove the TypeError from the exception chain in
#     464         # Python 3 (including for exceptions like SystemExit).
#     465         # Otherwise it looks like a bug in the code.
#     466         six.raise_from(e, None)
#
# File ~\anaconda3\Lib\http\client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File ~\anaconda3\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~\anaconda3\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~\anaconda3\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~\anaconda3\Lib\ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File ~\anaconda3\Lib\ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
def foursqare_places_of_interest(lat, lng, limit = 50):
    poi = query_foursquare_for_places(lat, lng, radius=1000)
    
    if poi:
        print("Nearby Places of Interest:")
        for places in poi:
            if 'coffee' in places['categories'][0]['name'].lower() or 'restaurant' in places['categories'][0]['name'].lower() or 'bar' in places['categories'][0]['name'].lower() or 'hotel' in places['categories'][0]['name'].lower():
                print(f"Business Category: {places['categories'][0]['name']}")
                if places['chains']:
                    print(f"Business Chain: {places['chains']}")
                print(f"Business Name: {places['name']}")
                print(f"Business Address: {places['location']['formatted_address']}")
                print("-" * 30)
    else:
        print("No Business found")

# %%
if bike_stations_df is not None:
    for index, row in bike_stations_df.iterrows():
        print(f"Station Name: {row['Station Name']}")
        print(f"Available Bikes: {row['Available Bikes']}")
        print(f"Empty Slots: {row['Empty Slots']}")
        print(f"Latitude: {row['Latitude']}")
        print(f"Longitude: {row['Longitude']}")
        
        
        foursqare_places_of_interest(row['Latitude'], row['Longitude'])
# Out:
# Station Name: W 100 St & Manhattan Ave
# Available Bikes: 3
# Empty Slots: 31
# Latitude: 40.795
# Longitude: -73.9645
# Nearby Places of Interest:
# Business Category: Coffee Shop
# Business Chain: [{'id': 'ab4c54c0-d68a-012e-5619-003048cad9da', 'name': 'Starbucks'}]
# Business Name: Starbucks
# Business Address: 805 Columbus Ave (at W 100th St), New York, NY 10025
# ------------------------------
# Business Category: Coffee Shop
# Business Name: Birch Coffee
# Business Address: 750 Columbus Ave (btwn W 96th & W 97th St), New York, NY 10025
# ------------------------------
# Business Category: Vietnamese Restaurant
# Business Name: Saiguette
# Business Address: 935 Columbus Ave (at W 106th St), New York, NY 10025
# ------------------------------
# Business Category: Wine Bar
# Business Name: Buceo 95
# Business Address: 201 W 95th St (btwn Amsterdam Ave & Broadway), New York, NY 10025
# ------------------------------
# Station Name: 7 Ave & Central Park South
# Available Bikes: 16
# Empty Slots: 62
# Latitude: 40.7667405590595
# Longitude: -73.9790689945221
# Nearby Places of Interest:
# Business Category: Italian Restaurant
# Business Name: Marea
# Business Address: 240 Central Park S (at 59th St & Broadway), New York, NY 10019
# ------------------------------
# Business Category: Fast Food Restaurant
# Business Chain: [{'id': '2fcf0650-9c63-0132-6632-3c15c2dde6c8', 'name': 'Pret a Manger'}]
# Business Name: Pret A Manger
# Business Address: 100 Central Park S, New York, NY 10019
# ------------------------------
# Business Category: Fast Food Restaurant
# Business Name: Souvlaki GR
# Business Address: 162 W 56th St (btwn 6th Ave & 7th Ave), New York, NY 10019
# ------------------------------
# Business Category: Sushi Restaurant
# Business Name: SUGARFISH by sushi nozawa
# Business Address: 210 W 56th St (West 56th Street), New York, NY 10019
# ------------------------------
# Business Category: American Restaurant
# Business Name: Quality Meats
# Business Address: 57 W 58th St (at 6th Ave), New York, NY 10019
# ------------------------------
# Station Name: Bedford Ave & Bergen St
# Available Bikes: 1
# Empty Slots: 16
# Latitude: 40.676368
# Longitude: -73.952918
# Nearby Places of Interest:
# Business Category: Coffee Shop
# Business Name: Cafe Con Libros
# Business Address: 724 Prospect Pl (Rogers Ave), Brooklyn, NY 11216
# ------------------------------
# Business Category: Bar
# Business Name: Rialto Grande
# Business Address: 644 Franklin Ave, Brooklyn, NY 11238
# ------------------------------
# Business Category: Cocktail Bar
# Business Name: St Ends
# Business Address: 667 Franklin Ave, Brooklyn, NY 11238
# ------------------------------
# Business Category: Cocktail Bar
# Business Name: King Tai
# Business Address: 1095 Bergen St (at Nostrand Ave), Brooklyn, NY 11216
# ------------------------------
# Business Category: Bar
# Business Name: Endless Life Brewing
# Business Address: 585 Franklin Ave, Brooklyn, NY 11238
# ------------------------------
# Station Name: 28 St & 41 Ave
# Available Bikes: 6
# Empty Slots: 18
# Latitude: 40.751047
# Longitude: -73.93797
# Nearby Places of Interest:
# Business Category: Coffee Shop
# Business Name: Chip City - LIC
# Business Address: 4215 Crescent St (btwn Queens Plaza S & 42nd Rd), Queens, NY 11101
# ------------------------------
# Business Category: Bar
# Business Name: THE HUNTRESS whiskey n' wings
# Business Address: 2403 41st Ave (at 24th St), Long Island City, NY 11101
# ------------------------------
# Business Category: Coffee Shop
# Business Name: No Stress Coffee
# Business Address: 4277 Hunter St (btwn 42nd Rd & 43rd Ave), Queens, NY 11101
# ------------------------------
# Business Category: Cocktail Bar
# Business Name: Dutch Kills
# Business Address: 2724 Jackson Ave (btwn Queens & Dutch Kills St), Long Island City, NY 11101
# ------------------------------
# Business Category: Wine Bar
# Business Name: The Beast Next Door
# Business Address: 4251 27th St (btwn 43rd Ave & 42nd Rd), Long Island City, NY 11101
# ------------------------------
# Station Name: Frederick Douglass Blvd & W 112 St
# Available Bikes: 11
# Empty Slots: 17
# Latitude: 40.801694
# Longitude: -73.957145
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[152], line 10
#       6 print(f"Latitude: {row['Latitude']}")
#       7 print(f"Longitude: {row['Longitude']}")
# ---> 10 foursqare_places_of_interest(row['Latitude'], row['Longitude'])
#
# Cell In[151], line 2, in foursqare_places_of_interest(lat, lng, limit)
#       1 def foursqare_places_of_interest(lat, lng, limit = 50):
# ----> 2     poi = query_foursquare_for_places(lat, lng, radius=1000)
#       4     if poi:
#       5         print("Nearby Places of Interest:")
#
# Cell In[79], line 18, in query_foursquare_for_places(lat, lng, radius, limit)
#      15 headers['Authorization'] = api_key
#      17 try:
# ---> 18     response = requests.get(url, headers=headers, params=params)
#      19     #print(response)
#      20     #print("Response content:", response.content)  # Print the raw response content
#      21     response_data = response.json()
#
# File ~\anaconda3\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~\anaconda3\Lib\site-packages\requests\adapters.py:487, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     484     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     486 try:
# --> 487     resp = conn.urlopen(
#     488         method=request.method,
#     489         url=url,
#     490         body=request.body,
#     491         headers=request.headers,
#     492         redirect=False,
#     493         assert_same_host=False,
#     494         preload_content=False,
#     495         decode_content=False,
#     496         retries=self.max_retries,
#     497         timeout=timeout,
#     498         chunked=chunked,
#     499     )
#     501 except (ProtocolError, OSError) as err:
#     502     raise ConnectionError(err, request=request)
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461             httplib_response = conn.getresponse()
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     468     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     458 except TypeError:
#     459     # Python 3
#     460     try:
# --> 461         httplib_response = conn.getresponse()
#     462     except BaseException as e:
#     463         # Remove the TypeError from the exception chain in
#     464         # Python 3 (including for exceptions like SystemExit).
#     465         # Otherwise it looks like a bug in the code.
#     466         six.raise_from(e, None)
#
# File ~\anaconda3\Lib\http\client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File ~\anaconda3\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~\anaconda3\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~\anaconda3\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~\anaconda3\Lib\ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File ~\anaconda3\Lib\ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
business = []

# %%
if bike_stations_df is not None:
    for index, row in bike_stations_df.iterrows():
        results = query_foursquare_for_places(row['Latitude'], row['Longitude'], limit = 50)
        
        for each in results:
            if each['categories']:
                Category = each['categories'][0]['name']
            if each['name']:
                Name = each['name']
            if each['location']:
                Location = each['location']['formatted_address']
            
                      
            if 'coffee' in Category.lower() or 'restaurant' in Category.lower() or 'bar' in Category.lower() or 'hotel' in Category.lower():
                business.append({'Station Name': row['Station Name'], 'Business Category': Category, 'Business Name': Name, 'Address': Location})

# %%
foursquare_business_df = pd.DataFrame(business)

# %%
foursquare_business_df
# Out:
#                   Station Name      Business Category  \
# 0     W 100 St & Manhattan Ave            Coffee Shop
# 1     W 100 St & Manhattan Ave            Coffee Shop
# 2     W 100 St & Manhattan Ave               Dive Bar
# 3     W 100 St & Manhattan Ave  Vietnamese Restaurant
# 4     W 100 St & Manhattan Ave     Italian Restaurant
# ...                        ...                    ...
# 7728            32 Ave & 77 St                    Bar
# 7729            32 Ave & 77 St                    Bar
# 7730            32 Ave & 77 St      French Restaurant
# 7731            32 Ave & 77 St           Cocktail Bar
# 7732            32 Ave & 77 St       Greek Restaurant
#
#                   Business Name  \
# 0                     Starbucks
# 1                  Birch Coffee
# 2              Bob's Your Uncle
# 3                     Saiguette
# 4                   Osteria 106
# ...                         ...
# 7728        Cassidy's Ale House
# 7729  The Queensboro Restaurant
# 7730              Bistro Eloise
# 7731    Bocaito Cafe & Wine Bar
# 7732                      Plaka
#
#                                                 Address
# 0     805 Columbus Ave (at W 100th St), New York, NY...
# 1     750 Columbus Ave (btwn W 96th & W 97th St), Ne...
# 2     929 Columbus Ave (btwn W 105th & W 106th St), ...
# 3     935 Columbus Ave (at W 106th St), New York, NY...
# 4     53 W 106th St (Btwn Manhattan and Columbus), N...
# ...                                                 ...
# 7728             7502 31st Ave, East Elmhurst, NY 11370
# 7729      8002 Northern Blvd, Jackson Heights, NY 11372
# 7730             7557 31st Ave, East Elmhurst, NY 11370
# 7731      8115 Northern Blvd, Jackson Heights, NY 11372
# 7732             7561 31st Ave, East Elmhurst, NY 11370
#
# [7733 rows x 4 columns]

# %% [markdown]
# # Yelp

# %% [markdown]
# Send a request to Yelp with a small radius (1000m) for all the bike stations in your city of choice.

# %%
def query_yelp_for_places(lat, lng, radius = 1000, limit = 10):
    url = "https://api.yelp.com/v3/businesses/search"
    api_key = os.getenv('yelp_API')
    params = {
        "latitude": lat,
        "longitude": lng,
        "radius": radius
    }
    
    headers = {
        "Authorization": f"Bearer {api_key}"
    }
    
    try:
        response = requests.get(url, params=params, headers=headers)
        #print(response)
        #print(response.content)
        response_data= response.json()
        
        if 'businesses' in response_data:
            places = response_data['businesses']
            return places
        else:
            print("No Place of Interest found")
            return []
    except requests.exceptions.RequestException as e:
        print("Error making API request:", e)
        return []

# %%
if bike_stations_df is not None:
    for index, row in bike_stations_df.iterrows():
        print(f"Station Name: {row['Station Name']}")
        print(f"Available Bikes: {row['Available Bikes']}")
        print(f"Empty Slots: {row['Empty Slots']}")
        print(f"Latitude: {row['Latitude']}")
        print(f"Longitude: {row['Longitude']}")
        
        query_yelp_for_places(row['Latitude'], row['Longitude'])
# Out:
# Station Name: W 100 St & Manhattan Ave
# Available Bikes: 5
# Empty Slots: 29
# Latitude: 40.795
# Longitude: -73.9645
# <Response [429]>
# No Place of Interest found
# Station Name: 7 Ave & Central Park South
# Available Bikes: 2
# Empty Slots: 76
# Latitude: 40.7667405590595
# Longitude: -73.9790689945221
# <Response [429]>
# No Place of Interest found
# Station Name: Bedford Ave & Bergen St
# Available Bikes: 2
# Empty Slots: 15
# Latitude: 40.676368
# Longitude: -73.952918
# <Response [429]>
# No Place of Interest found
# Station Name: 28 St & 41 Ave
# Available Bikes: 12
# Empty Slots: 12
# Latitude: 40.751047
# Longitude: -73.93797
# <Response [429]>
# No Place of Interest found
# Station Name: Frederick Douglass Blvd & W 112 St
# Available Bikes: 14
# Empty Slots: 14
# Latitude: 40.801694
# Longitude: -73.957145
# <Response [429]>
# No Place of Interest found
# Station Name: 3 Ave & E 112 St
# Available Bikes: 16
# Empty Slots: 5
# Latitude: 40.795508
# Longitude: -73.941606
# <Response [429]>
# No Place of Interest found
# Station Name: 8 Ave & W 31 St
# Available Bikes: 89
# Empty Slots: 7
# Latitude: 40.7505853470215
# Longitude: -73.9946848154068
# <Response [429]>
# No Place of Interest found
# Station Name: Bergen St & Vanderbilt Ave
# Available Bikes: 3
# Empty Slots: 23
# Latitude: 40.6794388
# Longitude: -73.9680438
# <Response [429]>
# No Place of Interest found
# Station Name: Monroe St & Bedford Ave
# Available Bikes: 6
# Empty Slots: 12
# Latitude: 40.6851443
# Longitude: -73.95380904
# <Response [429]>
# No Place of Interest found
# Station Name: 35 Ave & 37 St
# Available Bikes: 16
# Empty Slots: 11
# Latitude: 40.7557327
# Longitude: -73.9236611
# <Response [429]>
# No Place of Interest found
# Station Name: Bank St & Hudson St
# Available Bikes: 10
# Empty Slots: 11
# Latitude: 40.73652889
# Longitude: -74.00618026
# <Response [429]>
# No Place of Interest found
# Station Name: Greenwich St & W Houston St
# Available Bikes: 66
# Empty Slots: 14
# Latitude: 40.728846
# Longitude: -74.008591
# <Response [429]>
# No Place of Interest found
# Station Name: Madison St & Clinton St
# Available Bikes: 9
# Empty Slots: 31
# Latitude: 40.71269042
# Longitude: -73.98776323
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[220], line 9
#       6 print(f"Latitude: {row['Latitude']}")
#       7 print(f"Longitude: {row['Longitude']}")
# ----> 9 query_yelp_for_places(row['Latitude'], row['Longitude'])
#
# Cell In[219], line 15, in query_yelp_for_places(lat, lng, radius, limit)
#      10 headers = {
#      11     "Authorization": f"Bearer {api_key}"
#      12 }
#      14 try:
# ---> 15     response = requests.get(url, params=params, headers=headers)
#      16     print(response)
#      17     #print(response.content)
#
# File ~\anaconda3\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~\anaconda3\Lib\site-packages\requests\adapters.py:487, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     484     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     486 try:
# --> 487     resp = conn.urlopen(
#     488         method=request.method,
#     489         url=url,
#     490         body=request.body,
#     491         headers=request.headers,
#     492         redirect=False,
#     493         assert_same_host=False,
#     494         preload_content=False,
#     495         decode_content=False,
#     496         retries=self.max_retries,
#     497         timeout=timeout,
#     498         chunked=chunked,
#     499     )
#     501 except (ProtocolError, OSError) as err:
#     502     raise ConnectionError(err, request=request)
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461             httplib_response = conn.getresponse()
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     468     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     458 except TypeError:
#     459     # Python 3
#     460     try:
# --> 461         httplib_response = conn.getresponse()
#     462     except BaseException as e:
#     463         # Remove the TypeError from the exception chain in
#     464         # Python 3 (including for exceptions like SystemExit).
#     465         # Otherwise it looks like a bug in the code.
#     466         six.raise_from(e, None)
#
# File ~\anaconda3\Lib\http\client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File ~\anaconda3\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~\anaconda3\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~\anaconda3\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~\anaconda3\Lib\ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File ~\anaconda3\Lib\ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
def yelp_places_of_interest(lat, lng, limit = 50):
    poi = query_yelp_for_places(lat, lng, radius = 1000, limit = 50)
    
    if poi:
        print("Nearby Places of Interest:")
        for places in poi:
            print(f"Business Category: {places['categories'][0]['title']}")
            print(f"Business Name: {places['name']}")
            print(f"No of Reviews: {places['review_count']}")
            print(f"Rating: {places['rating']}")
            print(f"Business Address: {places['location']['display_address'][0]}")
            print(f"Business Contact: {places['display_phone']}")
            print("-" * 30)
    else:
        print("No Business found")

# %%
if bike_stations_df is not None:
    for index, row in bike_stations_df.iterrows():
        print(f"Station Name: {row['Station Name']}")
        print(f"Available Bikes: {row['Available Bikes']}")
        print(f"Empty Slots: {row['Empty Slots']}")
        print(f"Latitude: {row['Latitude']}")
        print(f"Longitude: {row['Longitude']}")
        
        yelp_places_of_interest(row['Latitude'], row['Longitude'])
# Out:
# Station Name: W 100 St & Manhattan Ave
# Available Bikes: 3
# Empty Slots: 31
# Latitude: 40.795
# Longitude: -73.9645
# <Response [200]>
# Nearby Places of Interest:
# Business Category: Comfort Food
# Business Name: Jacob's Pickles
# No of Reviews: 5402
# Rating: 4.0
# Business Address: 509 Amsterdam Ave
# Business Contact: (212) 470-5566
# ------------------------------
# Business Category: Vietnamese
# Business Name: Saiguette
# No of Reviews: 729
# Rating: 4.5
# Business Address: 935 Columbus Ave
# Business Contact: (212) 866-6888
# ------------------------------
# Business Category: Sardinian
# Business Name: Arco Cafe
# No of Reviews: 352
# Rating: 4.5
# Business Address: 886 Amsterdam Ave
# Business Contact: (646) 781-9080
# ------------------------------
# Business Category: Cocktail Bars
# Business Name: Nobody Told Me
# No of Reviews: 236
# Rating: 4.5
# Business Address: 951 Amsterdam Ave
# Business Contact:
# ------------------------------
# Business Category: Bars
# Business Name: The Calaveras
# No of Reviews: 231
# Rating: 4.5
# Business Address: 949 Columbus Ave
# Business Contact: (646) 484-6533
# ------------------------------
# Business Category: Noodles
# Business Name: The Tang - Upper West Side
# No of Reviews: 302
# Rating: 4.5
# Business Address: 920 Amsterdam Ave
# Business Contact: (646) 596-7970
# ------------------------------
# Business Category: French
# Business Name: Amelie
# No of Reviews: 297
# Rating: 4.5
# Business Address: 566 Amsterdam Ave
# Business Contact: (646) 422-7167
# ------------------------------
# Business Category: Italian
# Business Name: Fumo- Upper West Side
# No of Reviews: 237
# Rating: 4.0
# Business Address: 2791 Broadway
# Business Contact: (646) 822-2921
# ------------------------------
# Business Category: American (Traditional)
# Business Name: The Ellington
# No of Reviews: 139
# Rating: 4.5
# Business Address: 2745 Broadway
# Business Contact: (212) 281-3011
# ------------------------------
# Business Category: Breakfast & Brunch
# Business Name: Tiki Chick
# No of Reviews: 290
# Rating: 4.5
# Business Address: 517 Amsterdam Ave
# Business Contact:
# ------------------------------
# Business Category: Japanese
# Business Name: Sushi W
# No of Reviews: 168
# Rating: 4.5
# Business Address: 2673 Broadway
# Business Contact: (917) 318-9739
# ------------------------------
# Business Category: Burgers
# Business Name: Bareburger - Upper West Side
# No of Reviews: 393
# Rating: 3.5
# Business Address: 795 Columbus Ave
# Business Contact: (646) 559-2986
# Business Category: Bagels
# Business Name: Russ & Daughters - Brooklyn
# No of Reviews: 103
# Rating: 3.0
# Business Address: 141 Flushing Ave
# Business Contact: (212) 475-4880
# ------------------------------
# Business Category: American (Traditional)
# Business Name: Rustik Tavern
# No of Reviews: 589
# Rating: 4.0
# Business Address: 471 Dekalb Ave
# Business Contact: (347) 406-9700
# ------------------------------
# Business Category: American (New)
# Business Name: Walter's
# No of Reviews: 629
# Rating: 4.0
# Business Address: 166 DeKalb Ave
# Business Contact: (718) 488-7800
# ------------------------------
# Business Category: Bars
# Business Name: LaRina Pastificio & Vino
# No of Reviews: 227
# Rating: 4.0
# Business Address: 387 Myrtle Ave
# Business Contact: (718) 852-0001
# ------------------------------
# Business Category: Korean
# Business Name: Tiger Box
# No of Reviews: 80
# Rating: 4.5
# Business Address: 169 Park Ave
# Business Contact: (646) 320-1177
# ------------------------------
# Business Category: Delis
# Business Name: Farmer In the Deli
# No of Reviews: 196
# Rating: 4.5
# Business Address: 357 Myrtle Ave
# Business Contact: (718) 875-9067
# ------------------------------
# Business Category: Sushi Bars
# Business Name: U-gu
# No of Reviews: 189
# Rating: 4.5
# Business Address: 541 Myrtle Ave
# Business Contact: (718) 857-0222
# ------------------------------
# Business Category: Japanese
# Business Name: 1 OR 8
# No of Reviews: 429
# Rating: 4.0
# Business Address: 229 Dekalb Ave
# Business Contact: (718) 384-2152
# ------------------------------
# Business Category: Patisserie/Cake Shop
# Business Name: Le Petit Monstre
# No of Reviews: 55
# Rating: 4.5
# Business Address: 82 Washington Ave
# Business Contact:
# ------------------------------
# Station Name: Rivington St & Ridge St
# Available Bikes: 50
# Empty Slots: 6
# Latitude: 40.71850211
# Longitude: -73.98329859
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[156], line 9
#       6 print(f"Latitude: {row['Latitude']}")
#       7 print(f"Longitude: {row['Longitude']}")
# ----> 9 yelp_places_of_interest(row['Latitude'], row['Longitude'])
#
# Cell In[155], line 2, in yelp_places_of_interest(lat, lng, limit)
#       1 def yelp_places_of_interest(lat, lng, limit = 50):
# ----> 2     poi = query_yelp_for_places(lat, lng, radius = 1000, limit = 50)
#       4     if poi:
#       5         print("Nearby Places of Interest:")
#
# Cell In[153], line 15, in query_yelp_for_places(lat, lng, radius, limit)
#      10 headers = {
#      11     "Authorization": f"Bearer {api_key}"
#      12 }
#      14 try:
# ---> 15     response = requests.get(url, params=params, headers=headers)
#      16     print(response)
#      17     #print(response.content)
#
# File ~\anaconda3\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~\anaconda3\Lib\site-packages\requests\adapters.py:487, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     484     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     486 try:
# --> 487     resp = conn.urlopen(
#     488         method=request.method,
#     489         url=url,
#     490         body=request.body,
#     491         headers=request.headers,
#     492         redirect=False,
#     493         assert_same_host=False,
#     494         preload_content=False,
#     495         decode_content=False,
#     496         retries=self.max_retries,
#     497         timeout=timeout,
#     498         chunked=chunked,
#     499     )
#     501 except (ProtocolError, OSError) as err:
#     502     raise ConnectionError(err, request=request)
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     461             httplib_response = conn.getresponse()
#     462         except BaseException as e:
#     463             # Remove the TypeError from the exception chain in
#     464             # Python 3 (including for exceptions like SystemExit).
#     465             # Otherwise it looks like a bug in the code.
# --> 466             six.raise_from(e, None)
#     467 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     468     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:461, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     458 except TypeError:
#     459     # Python 3
#     460     try:
# --> 461         httplib_response = conn.getresponse()
#     462     except BaseException as e:
#     463         # Remove the TypeError from the exception chain in
#     464         # Python 3 (including for exceptions like SystemExit).
#     465         # Otherwise it looks like a bug in the code.
#     466         six.raise_from(e, None)
#
# File ~\anaconda3\Lib\http\client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File ~\anaconda3\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~\anaconda3\Lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~\anaconda3\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~\anaconda3\Lib\ssl.py:1278, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1274     if flags != 0:
#    1275         raise ValueError(
#    1276           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1277           self.__class__)
# -> 1278     return self.read(nbytes, buffer)
#    1279 else:
#    1280     return super().recv_into(buffer, nbytes, flags)
#
# File ~\anaconda3\Lib\ssl.py:1134, in SSLSocket.read(self, len, buffer)
#    1132 try:
#    1133     if buffer is not None:
# -> 1134         return self._sslobj.read(len, buffer)
#    1135     else:
#    1136         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
restaurants = []

# %%
if bike_stations1_df is not None:
    for index, row in bike_stations1_df.iterrows():
        results = query_yelp_for_places(row['Latitude'], row['Longitude'], radius = 1000, limit = 50)
        
        for each in results:
            if each['categories']:
                Category = each['categories'][0]['title']
            if each['name']:
                Name = each['name']
            if each['review_count']:
                Count_of_Reviews = each['review_count']
            if each['rating']:
                Rating = each['rating']
            if each['location']['display_address']:
                Address = each['location']['display_address'][0]
            if each['display_phone']:
                Contact = each['display_phone']
                
            restaurants.append({'Station Name': row['Station Name'], 'Station Latitude': row['Latitude'], 'Station Longitude': row['Longitude'], 'Business Category': Category, 'Business Name': Name, 'Rating': Rating, 'Number of Reviews': Count_of_Reviews, 'Address': Address, 'Contact': Contact})

# %%
if bike_stations2_df is not None:
    for index, row in bike_stations2_df.iterrows():
        results = query_yelp_for_places(row['Latitude'], row['Longitude'], radius = 1000, limit = 50)
        
        for each in results:
            if each['categories']:
                Category = each['categories'][0]['title']
            if each['name']:
                Name = each['name']
            if each['review_count']:
                Count_of_Reviews = each['review_count']
            if each['rating']:
                Rating = each['rating']
            if each['location']['display_address']:
                Address = each['location']['display_address'][0]
            if each['display_phone']:
                Contact = each['display_phone']
                
            restaurants.append({'Station Name': row['Station Name'], 'Station Latitude': row['Latitude'], 'Station Longitude': row['Longitude'], 'Business Category': Category, 'Business Name': Name, 'Rating': Rating, 'Number of Reviews': Count_of_Reviews, 'Address': Address, 'Contact': Contact})

# %%
yelp_business_df = pd.DataFrame(restaurants)

# %%
yelp_business_df.to_csv('yelp_business.csv')

# %% [markdown]
# # Comparing Results

# %% [markdown]
# Which API provided you with more complete data? Provide an explanation.

# %% [markdown]
# Yelp API provided me with a lot more data than Four Square API. I was only able to extract three data points from Four Square: The business name, category and location. Other data provided does not provide any value to the current exercise. On the other hand, Yelp offers additional information such as the number of reviews, the rating, type of transactions offered (pick up or delivery), the currency accepted and a phone number to contact the business.

# %% [markdown]
# Get the top 10 restaurants according to their rating

# %%
Top_10_Restaurants = yelp_business_df.sort_values(by='Rating', ascending = False).head(10)
print(Top_10_Restaurants)
# Out:
#                          Station Name  Station Latitude  Station Longitude  \
# 23003    St. Ann's Av & Bruckner Blvd         40.803399         -73.919763
# 27694                 E 11 St & 1 Ave         40.729538         -73.984267
# 11637         Cypress Ave & George St         40.698120         -73.902710
# 13385          Melrose Ave & E 150 St         40.816827         -73.917338
# 15401        Broadway & Kosciuszko St         40.693290         -73.928520
# 21942  Willoughby Ave & Onderdonk Ave         40.709800         -73.917270
# 20612        Frost St & Debevoise Ave         40.718820         -73.939480
# 20610        Frost St & Debevoise Ave         40.718820         -73.939480
# 6559               Carroll St & 5 Ave         40.675162         -73.981483
# 7546       Kingston Ave & Herkimer St         40.678907         -73.941428
#
#         Business Category             Business Name  Rating  \
# 23003              French                MAiSONETTA     5.0
# 27694            Japanese  Sushi Lab - East Village     5.0
# 11637               Pizza                       Pan     5.0
# 13385              French                MAiSONETTA     5.0
# 15401                Bars               Wonderville     5.0
# 21942               Ramen                     Za-Ya     5.0
# 20612             Italian     Pomp and Circumstance     5.0
# 20610  Breakfast & Brunch       Silver Light Tavern     5.0
# 6559                 Pubs          The Commissioner     5.0
# 7546            Wine Bars     Kingston Public House     5.0
#
#        Number of Reviews           Address         Contact
# 23003                 55   141 Lincoln Ave  (347) 297-4607
# 27694                 76  320 East 11th St  (212) 665-3737
# 11637                 31   1563 Decatur St  (718) 885-4126
# 13385                 55   141 Lincoln Ave  (347) 297-4607
# 15401                 24     1186 Broadway  (347) 413-9695
# 21942                 30      321 Starr St  (929) 460-5929
# 20612                160    577 Lorimer St  (718) 387-4861
# 20610                108    689 Lorimer St  (718) 963-0384
# 6559                 162       247 5th Ave  (347) 689-3968
# 7546                  28  100 Kingston Ave  (347) 295-1438
